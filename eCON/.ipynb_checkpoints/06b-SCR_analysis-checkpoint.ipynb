# %% [markdown]
# from IPython.display import HTML
#
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %% [markdown]
# # **Analysis of SCR and brain response for shock**

# %%
from IPython.core.debugger import set_trace

import pandas as pd
import numpy as np
import os
from os.path import join, isdir, dirname, basename, exists
from os import mkdir
import glob as glob
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(context="paper",style="white",font_scale=1.5)

# %%
eCON = '/data/bswift-1/Pessoa_Lab/eCON'
SCR_betapath = join(eCON,'SCR_new/dataset/results_ShockUncensored/{subj}/{group}lable/splitted_regs/{subj}_bucket_REML_clean.1D')
roi_betapath = join(eCON,'dataset/results_ShockUncensored/{subj}/{group}lable/splitted_regs/ROI_{roi}/noProx/{subj}_bucket_REML.1D')
yoked = pd.read_excel(join(eCON,'SCR_new/scripts/CON_yoked_table.xlsx'))
yoked = yoked.query('use == 1')

# %%
rois = 'rvAI rdAI lvAI ldAI rPI lPI rBNST lBNST ACC\
        Amygdala_BLBM_La_R Amygdala_CeME_R Amygdala_BLBM_La_L Amygdala_CeME_L\
        rCa lCa rPa lPa rVS lVS vmPFC PCC1 PCC2 rPAG1 lPAG1'.split()

# %%
count = 0
df = pd.DataFrame()
for i, row in yoked.iterrows():
    for kind in ['control','uncontrol']:
        #print(row[kind])
        
        scr_beta = np.loadtxt(SCR_betapath.format(subj=row[kind],group=kind))[1::2][-1]
        roi_beta = np.vstack([np.loadtxt(roi_betapath.format(subj=row[kind],roi=roi,group=kind))[1::2][-1] for roi in rois]).T
        all_betas = np.append(scr_beta,roi_beta)

        tmp_df = pd.DataFrame(all_betas, index=['SCR']+rois).T
        tmp_df['SubjID'] = row[kind]
        tmp_df['Group'] = kind
        tmp_df['Pair'] = 'P{:02d}'.format(i)
        df = pd.concat([df,tmp_df],axis =0)

# %%
df.columns
# Out:
# Index(['SCR', 'rvAI', 'rdAI', 'lvAI', 'ldAI', 'rPI', 'lPI', 'rBNST', 'lBNST',
#        'ACC', 'Amygdala_BLBM_La_R', 'Amygdala_CeME_R', 'Amygdala_BLBM_La_L',
#        'Amygdala_CeME_L', 'rCa', 'lCa', 'rPa', 'lPa', 'rVS', 'lVS', 'vmPFC',
#        'PCC1', 'PCC2', 'rPAG1', 'lPAG1', 'SubjID', 'Group', 'Pair'],
#       dtype='object')

# %%
df_rBNST = df[['Pair','Group','SubjID','rBNST','SCR']]
df_rBNST.reset_index(drop=True,inplace=True)

# %%
df_rBNST_pairs = df[['Pair','rBNST','SCR']].groupby(['Pair'],as_index=True).diff()
df_rBNST_pairs.dropna(axis=0,how='all',inplace=True)
df_rBNST_pairs.index = pd.Series(df_rBNST.Pair.unique(),name='Pair')
df_rBNST_pairs.head()
# Out:
#          rBNST       SCR
# Pair
# P00   0.554184 -2.574000
# P01  -0.673879  1.632302
# P02  -0.640979  0.914620
# P03   0.163446  1.775880
# P04   0.189221 -0.039070

# %%
sns.scatterplot(x='rBNST',y='SCR',data=df_rBNST_pairs,s=50)

# %%
sns.regplot(x='rBNST',y='SCR',data=df_rBNST_pairs)

# %%
cov_df = pd.read_csv(join(eCON,'dataset/data_for_RBA/uncon_v_con_ROI24_with_covariates.txt'),sep='\t',index_col=['Subj','ROI'])

# %%
cov_df
# Out:
#                               Y  TRAITmean  TRAITdiff  STATEmean  STATEdiff
# Subj ROI
# P00  vmPFC               0.0915    -1.0030    -0.0406    -1.2307    -0.1812
#      PCC1                0.5290    -1.0030    -0.0406    -1.2307    -0.1812
#      PCC2                0.3904    -1.0030    -0.0406    -1.2307    -0.1812
#      rPAG1               0.6907    -1.0030    -0.0406    -1.2307    -0.1812
#      lPAG1              -0.0709    -1.0030    -0.0406    -1.2307    -0.1812
#      rvAI                0.1475    -1.0030    -0.0406    -1.2307    -0.1812
#      rdAI                0.6978    -1.0030    -0.0406    -1.2307    -0.1812
#      lvAI               -0.2128    -1.0030    -0.0406    -1.2307    -0.1812
#      ldAI                0.3007    -1.0030    -0.0406    -1.2307    -0.1812
#      rPI                 0.9365    -1.0030    -0.0406    -1.2307    -0.1812
#      lPI                 0.6025    -1.0030    -0.0406    -1.2307    -0.1812
#      rBNST               0.5542    -1.0030    -0.0406    -1.2307    -0.1812
#      lBNST               1.0739    -1.0030    -0.0406    -1.2307    -0.1812
#      ACC                 0.3396    -1.0030    -0.0406    -1.2307    -0.1812
#      Amygdala_BLBM_La_R  0.1321    -1.0030    -0.0406    -1.2307    -0.1812
#      Amygdala_CeME_R     0.2312    -1.0030    -0.0406    -1.2307    -0.1812
#      Amygdala_BLBM_La_L -0.0890    -1.0030    -0.0406    -1.2307    -0.1812
#      Amygdala_CeME_L     0.1638    -1.0030    -0.0406    -1.2307    -0.1812
#      rCa                 0.1302    -1.0030    -0.0406    -1.2307    -0.1812
#      lCa                 0.0605    -1.0030    -0.0406    -1.2307    -0.1812
#      rPa                 0.2266    -1.0030    -0.0406    -1.2307    -0.1812
#      lPa                -0.0648    -1.0030    -0.0406    -1.2307    -0.1812
#      rVS                 0.0605    -1.0030    -0.0406    -1.2307    -0.1812
#      lVS                 0.2266    -1.0030    -0.0406    -1.2307    -0.1812
# P01  vmPFC              -0.2815    -0.4359     3.1472    -0.4379     0.4163
#      PCC1               -0.3584    -0.4359     3.1472    -0.4379     0.4163
#      PCC2               -0.3584    -0.4359     3.1472    -0.4379     0.4163
#      rPAG1               0.2227    -0.4359     3.1472    -0.4379     0.4163
#      lPAG1               0.5879    -0.4359     3.1472    -0.4379     0.4163
#      rvAI                0.2782    -0.4359     3.1472    -0.4379     0.4163
# ...                         ...        ...        ...        ...        ...
# P61  rCa                -0.2356     0.1312    -0.7491    -0.0416     0.9142
#      lCa                -0.5957     0.1312    -0.7491    -0.0416     0.9142
#      rPa                -0.4551     0.1312    -0.7491    -0.0416     0.9142
#      lPa                -0.1928     0.1312    -0.7491    -0.0416     0.9142
#      rVS                -0.5957     0.1312    -0.7491    -0.0416     0.9142
#      lVS                -0.4551     0.1312    -0.7491    -0.0416     0.9142
# P62  vmPFC              -0.3181     0.5723    -1.1033     0.8304    -1.1771
#      PCC1               -0.8937     0.5723    -1.1033     0.8304    -1.1771
#      PCC2               -0.9409     0.5723    -1.1033     0.8304    -1.1771
#      rPAG1               0.1368     0.5723    -1.1033     0.8304    -1.1771
#      lPAG1              -0.1642     0.5723    -1.1033     0.8304    -1.1771
#      rvAI                0.9399     0.5723    -1.1033     0.8304    -1.1771
#      rdAI                0.3063     0.5723    -1.1033     0.8304    -1.1771
#      lvAI                0.0544     0.5723    -1.1033     0.8304    -1.1771
#      ldAI                0.2607     0.5723    -1.1033     0.8304    -1.1771
#      rPI                 0.0713     0.5723    -1.1033     0.8304    -1.1771
#      lPI                -0.2218     0.5723    -1.1033     0.8304    -1.1771
#      rBNST               0.6160     0.5723    -1.1033     0.8304    -1.1771
#      lBNST               0.1348     0.5723    -1.1033     0.8304    -1.1771
#      ACC                -0.0592     0.5723    -1.1033     0.8304    -1.1771
#      Amygdala_BLBM_La_R -0.5092     0.5723    -1.1033     0.8304    -1.1771
#      Amygdala_CeME_R    -0.7134     0.5723    -1.1033     0.8304    -1.1771
#      Amygdala_BLBM_La_L -0.5901     0.5723    -1.1033     0.8304    -1.1771
#      Amygdala_CeME_L    -0.6077     0.5723    -1.1033     0.8304    -1.1771
#      rCa                 0.0658     0.5723    -1.1033     0.8304    -1.1771
#      lCa                 0.2057     0.5723    -1.1033     0.8304    -1.1771
#      rPa                -0.0397     0.5723    -1.1033     0.8304    -1.1771
#      lPa                -0.1882     0.5723    -1.1033     0.8304    -1.1771
#      rVS                 0.2057     0.5723    -1.1033     0.8304    -1.1771
#      lVS                -0.0397     0.5723    -1.1033     0.8304    -1.1771
#
# [1464 rows x 5 columns]
