# %%
library(IRdisplay)

display_html(
'<script>  
code_show=true; 
function code_toggle() {
  if (code_show){
    $(\'div.input\').hide();
  } else {
    $(\'div.input\').show();
  }
  code_show = !code_show
}  
$( document ).ready(code_toggle);
</script>
  <form action="javascript:code_toggle()">
    <input type="submit" value="Click here to toggle on/off the raw code.">
 </form>'
)
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#   if (code_show){
#     $('div.input').hide();
#   } else {
#     $('div.input').show();
#   }
#   code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#   <form action="javascript:code_toggle()">
#     <input type="submit" value="Click here to toggle on/off the raw code.">
#  </form>

# %%
library(brms)
library(haven) # to load the SPSS .sav file
library(tidyverse) # needed for data manipulation.
library(RColorBrewer) # needed for some extra colours in one of the graphs
library(ggmcmc)
library(ggthemes)
library(ggridges)

# IMPORT VISUALIZATION LIBRARIES:
library(data.table)
library(ggplot2)
library(ggridges)
library(dplyr)
library(tidyr)
library(scales)
library(viridis)

# %%
df <- read.table('uncon_v_con_shock_MR_ROI24final_with_covariates.txt',header = TRUE,sep = "\t")
head(df)
# Out:
#   Subj ROI               Y       TRAITmean TRAITdiff STATEmean STATEdiff
# 1 P00  L Amygdala (BLBM) -0.0841 -1.003    -0.0406   -1.2307   -0.1812
# 2 P00  R Amygdala (BLBM)  0.1305 -1.003    -0.0406   -1.2307   -0.1812
# 3 P00  L Amygdala (CeME)  0.1827 -1.003    -0.0406   -1.2307   -0.1812
# 4 P00  R Amygdala (CeME)  0.2318 -1.003    -0.0406   -1.2307   -0.1812
# 5 P00  L aMCC             1.3089 -1.003    -0.0406   -1.2307   -0.1812
# 6 P00  R aMCC             0.8594 -1.003    -0.0406   -1.2307   -0.1812
#   BPdiff_stdz
# 1 -0.8664
# 2 -0.8664
# 3 -0.8664
# 4 -0.8664
# 5 -0.8664
# 6 -0.8664

# %% [markdown]
# # **1. Bayesian Multi-level modeling**

# %% [markdown]
# ## **Model 1: Varying intercept and varying slope model.**
# ROIs will have varying intercepts and varying slopes for every independent variable.
#
# $$Y \sim Student\_t(\nu,\mu_{s,r},\sigma^{2}_{\epsilon})$$
# $$\mu_{s,r} = \alpha + \alpha_{SUB} + \alpha_{ROI} + (\beta_{TM}+\beta_{ROI_{TM}})*TM + (\beta_{TD}+\beta_{ROI_{TD}})*TD + (\beta_{SM}+\beta_{ROI_{SM}})*SM + (\beta_{SD}+\beta_{ROI_{SD}})*SD + (\beta_{BPD}+\beta_{ROI_{BPD}})*BPD \epsilon$$
#
# ## **Priors**
# $$\alpha \sim Student\_t(3,0,10)$$
# $$\alpha_{SUB} \sim Student\_t(\nu_{SUB},0,\sigma_{SUB})$$
# $$\sigma_{SUB} \sim Student\_t(3,0,10)$$
# $$\nu_{SUB} \sim \Gamma(3.325,0.1)$$
# $$\alpha_{ROI} \sim Student\_t(\nu_{ROI},0,\sigma_{ROI})$$
# $$\sigma_{ROI} \sim Student\_t(3,0,10)$$
# $$\nu_{ROI} \sim \Gamma(3.325,0.1)$$
# $$\beta_{TM} \sim Student\_t(3,0,10)$$
# $$\beta_{TD} \sim Student\_t(3,0,10)$$
# $$\beta_{SM} \sim Student\_t(3,0,10)$$
# $$\beta_{SD} \sim Student\_t(3,0,10)$$
# $$\beta_{BPD} \sim Student\_t(3,0,10)$$
# $$\beta_{ROI_{TM}} \sim Student\_t(3,0,10)$$
# $$\beta_{ROI_{TD}} \sim Student\_t(3,0,10)$$
# $$\beta_{ROI_{SM}} \sim Student\_t(3,0,10)$$
# $$\beta_{ROI_{SD}} \sim Student\_t(3,0,10)$$
# $$\beta_{ROI_{BPD}} \sim Student\_t(3,0,10)$$
#
# $$\nu \sim \Gamma(3.325,0.1)$$
# $$\sigma_{\epsilon} \sim Student\_t(3,0,10)$$
#
# Where,
# TM: Trait mean
# TD: Triat difference
# SM: State mean
# SD: State difference
# BPD: button press difference

# %%
mod = '1 + STATEmean + TRAITmean + STATEdiff + TRAITdiff + BPdiff_stdz'
modelForm = paste('Y ~',mod,'+ (1 | gr(Subj, dist= "student")) + (',mod,'| gr(ROI, dist="student"))')
priorRBA <- get_prior(formula = modelForm,data=df,family = 'student')
priorRBA$prior[2:6] <- "student_t(3,0,10)"
priorRBA$prior[9:10] <- "gamma(3.325,0.1)"
priorRBA$prior[12] <- "gamma(3.325,0.1)"
priorRBA
# Out:
#    prior               class     coef        group resp dpar nlpar bound
# 1                      b
# 2  student_t(3,0,10)   b         BPdiff_stdz
# 3  student_t(3,0,10)   b         STATEdiff
# 4  student_t(3,0,10)   b         STATEmean
# 5  student_t(3,0,10)   b         TRAITdiff
# 6  student_t(3,0,10)   b         TRAITmean
# 7  lkj(1)              cor
# 8                      cor                   ROI
# 9  gamma(3.325,0.1)    df                    ROI
# 10 gamma(3.325,0.1)    df                    Subj
# 11 student_t(3, 0, 10) Intercept
# 12 gamma(3.325,0.1)    nu
# 13 student_t(3, 0, 10) sd
# 14                     sd                    ROI
# 15                     sd        BPdiff_stdz ROI
# 16                     sd        Intercept   ROI
# 17                     sd        STATEdiff   ROI
# 18                     sd        STATEmean   ROI
# 19                     sd        TRAITdiff   ROI
# 20                     sd        TRAITmean   ROI
# 21                     sd                    Subj
# 22                     sd        Intercept   Subj
# 23 student_t(3, 0, 10) sigma

# %%
iterations <- 10000
chains <- 4
SCALE <- 1
ns <- iterations*chains/2


qVars = 'STATEmean,TRAITmean,STATEdiff,TRAITdiff,BPdiff_stdz'
EOI = 'Intercept,STATEmean,TRAITmean,STATEdiff,TRAITdiff,BPdiff_stdz'
EOIq <- strsplit(qVars, '\\,')[[1]]
if(!('Intercept' %in% EOIq)) EOIq <- c('Intercept', EOIq)
EOIq <- intersect(strsplit(EOI, '\\,')[[1]], EOIq)
EOIq


dataTable <- df

# number of ROIs
nR <- nlevels(dataTable$ROI)

# number of sigfigs to show on the table
nfigs <- 4

head(dataTable)
# Out:
# [1] "Intercept"   "STATEmean"   "TRAITmean"   "STATEdiff"   "TRAITdiff"
# [6] "BPdiff_stdz"
#   Subj ROI               Y       TRAITmean TRAITdiff STATEmean STATEdiff
# 1 P00  L Amygdala (BLBM) -0.0841 -1.003    -0.0406   -1.2307   -0.1812
# 2 P00  R Amygdala (BLBM)  0.1305 -1.003    -0.0406   -1.2307   -0.1812
# 3 P00  L Amygdala (CeME)  0.1827 -1.003    -0.0406   -1.2307   -0.1812
# 4 P00  R Amygdala (CeME)  0.2318 -1.003    -0.0406   -1.2307   -0.1812
# 5 P00  L aMCC             1.3089 -1.003    -0.0406   -1.2307   -0.1812
# 6 P00  R aMCC             0.8594 -1.003    -0.0406   -1.2307   -0.1812
#   BPdiff_stdz
# 1 -0.8664
# 2 -0.8664
# 3 -0.8664
# 4 -0.8664
# 5 -0.8664
# 6 -0.8664

# %%
fm <- brm(modelForm,
          data=dataTable,
          chains = chains,
          family = 'student',
          prior = priorRBA,
          inits=0, iter=iterations, 
          control = list(adapt_delta = 0.99, max_treedepth = 15))
# Out:
# Compiling the C++ model
#
# Start sampling
# SAMPLING FOR MODEL 'd956566839e0c186dd6f90e1bdca9876' NOW (CHAIN 1).
# Chain 1:
# Chain 1: Gradient evaluation took 0 seconds
# Chain 1: 1000 transitions using 10 leapfrog steps per transition would take 0 seconds.
# Chain 1: Adjust your expectations accordingly!
# Chain 1:
# Chain 1:
# Chain 1: Iteration:    1 / 10000 [  0%]  (Warmup)
# Chain 1: Iteration: 1000 / 10000 [ 10%]  (Warmup)
# Chain 1: Iteration: 2000 / 10000 [ 20%]  (Warmup)
# Chain 1: Iteration: 3000 / 10000 [ 30%]  (Warmup)
# Chain 1: Iteration: 4000 / 10000 [ 40%]  (Warmup)
# Chain 1: Iteration: 5000 / 10000 [ 50%]  (Warmup)
# Chain 1: Iteration: 5001 / 10000 [ 50%]  (Sampling)
# Chain 1: Iteration: 6000 / 10000 [ 60%]  (Sampling)
# Chain 1: Iteration: 7000 / 10000 [ 70%]  (Sampling)
# Chain 1: Iteration: 8000 / 10000 [ 80%]  (Sampling)
# Chain 1: Iteration: 9000 / 10000 [ 90%]  (Sampling)
# Chain 1: Iteration: 10000 / 10000 [100%]  (Sampling)
# Chain 1:
# Chain 1:  Elapsed Time: 916.27 seconds (Warm-up)
# Chain 1:                976.3 seconds (Sampling)
# Chain 1:                1892.57 seconds (Total)
# Chain 1:
#
# SAMPLING FOR MODEL 'd956566839e0c186dd6f90e1bdca9876' NOW (CHAIN 2).
# Chain 2:
# Chain 2: Gradient evaluation took 0 seconds
# Chain 2: 1000 transitions using 10 leapfrog steps per transition would take 0 seconds.
# Chain 2: Adjust your expectations accordingly!
# Chain 2:
# Chain 2:
# Chain 2: Iteration:    1 / 10000 [  0%]  (Warmup)
# Chain 2: Iteration: 1000 / 10000 [ 10%]  (Warmup)
# Chain 2: Iteration: 2000 / 10000 [ 20%]  (Warmup)
# Chain 2: Iteration: 3000 / 10000 [ 30%]  (Warmup)
# Chain 2: Iteration: 4000 / 10000 [ 40%]  (Warmup)
# Chain 2: Iteration: 5000 / 10000 [ 50%]  (Warmup)
# Chain 2: Iteration: 5001 / 10000 [ 50%]  (Sampling)
# Chain 2: Iteration: 6000 / 10000 [ 60%]  (Sampling)
# Chain 2: Iteration: 7000 / 10000 [ 70%]  (Sampling)
# Chain 2: Iteration: 8000 / 10000 [ 80%]  (Sampling)
# Chain 2: Iteration: 9000 / 10000 [ 90%]  (Sampling)
# Chain 2: Iteration: 10000 / 10000 [100%]  (Sampling)
# Chain 2:
# Chain 2:  Elapsed Time: 824.91 seconds (Warm-up)
# Chain 2:                911.18 seconds (Sampling)
# Chain 2:                1736.09 seconds (Total)
# Chain 2:
#
# SAMPLING FOR MODEL 'd956566839e0c186dd6f90e1bdca9876' NOW (CHAIN 3).
# Chain 3:
# Chain 3: Gradient evaluation took 0 seconds
# Chain 3: 1000 transitions using 10 leapfrog steps per transition would take 0 seconds.
# Chain 3: Adjust your expectations accordingly!
# Chain 3:
# Chain 3:
# Chain 3: Iteration:    1 / 10000 [  0%]  (Warmup)
# Chain 3: Iteration: 1000 / 10000 [ 10%]  (Warmup)
# Chain 3: Iteration: 2000 / 10000 [ 20%]  (Warmup)
# Chain 3: Iteration: 3000 / 10000 [ 30%]  (Warmup)
# Chain 3: Iteration: 4000 / 10000 [ 40%]  (Warmup)
# Chain 3: Iteration: 5000 / 10000 [ 50%]  (Warmup)
# Chain 3: Iteration: 5001 / 10000 [ 50%]  (Sampling)
# Chain 3: Iteration: 6000 / 10000 [ 60%]  (Sampling)
# Chain 3: Iteration: 7000 / 10000 [ 70%]  (Sampling)
# Chain 3: Iteration: 8000 / 10000 [ 80%]  (Sampling)
# Chain 3: Iteration: 9000 / 10000 [ 90%]  (Sampling)
# Chain 3: Iteration: 10000 / 10000 [100%]  (Sampling)
# Chain 3:
# Chain 3:  Elapsed Time: 1005.88 seconds (Warm-up)
# Chain 3:                510.19 seconds (Sampling)
# Chain 3:                1516.07 seconds (Total)
# Chain 3:
#
# SAMPLING FOR MODEL 'd956566839e0c186dd6f90e1bdca9876' NOW (CHAIN 4).
# Chain 4:
# Chain 4: Gradient evaluation took 0 seconds
# Chain 4: 1000 transitions using 10 leapfrog steps per transition would take 0 seconds.
# Chain 4: Adjust your expectations accordingly!
# Chain 4:
# Chain 4:
# Chain 4: Iteration:    1 / 10000 [  0%]  (Warmup)
# Chain 4: Iteration: 1000 / 10000 [ 10%]  (Warmup)
# Chain 4: Iteration: 2000 / 10000 [ 20%]  (Warmup)
# Chain 4: Iteration: 3000 / 10000 [ 30%]  (Warmup)
# Chain 4: Iteration: 4000 / 10000 [ 40%]  (Warmup)
# Chain 4: Iteration: 5000 / 10000 [ 50%]  (Warmup)
# Chain 4: Iteration: 5001 / 10000 [ 50%]  (Sampling)
# Chain 4: Iteration: 6000 / 10000 [ 60%]  (Sampling)
# Chain 4: Iteration: 7000 / 10000 [ 70%]  (Sampling)
# Chain 4: Iteration: 8000 / 10000 [ 80%]  (Sampling)
# Chain 4: Iteration: 9000 / 10000 [ 90%]  (Sampling)
# Chain 4: Iteration: 10000 / 10000 [100%]  (Sampling)
# Chain 4:
# Chain 4:  Elapsed Time: 793.36 seconds (Warm-up)
# Chain 4:                501.38 seconds (Sampling)
# Chain 4:                1294.74 seconds (Total)
# Chain 4:
# Warning message:
# “Bulk Effective Samples Size (ESS) is too low, indicating posterior means and medians may be unreliable.
# Running the chains for more iterations may help. See
# http://mc-stan.org/misc/warnings.html#bulk-ess”

# %%
cat(capture.output(summary(fm)),sep = '\n', append=TRUE)
# Out:
#  Family: student
#   Links: mu = identity; sigma = identity; nu = identity
# Formula: Y ~ 1 + STATEmean + TRAITmean + STATEdiff + TRAITdiff + BPdiff_stdz + (1 | gr(Subj, dist = "student")) + (1 + STATEmean + TRAITmean + STATEdiff + TRAITdiff + BPdiff_stdz | gr(ROI, dist = "student"))
#    Data: dataTable (Number of observations: 1464)
# Samples: 4 chains, each with iter = 10000; warmup = 5000; thin = 1;
#          total post-warmup samples = 20000
#
# Group-Level Effects:
# ~ROI (Number of levels: 24)
#                            Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS
# df                            31.72     17.98     6.72    75.27 1.00      865
# sd(Intercept)                  0.05      0.01     0.03     0.08 1.00     6328
# sd(STATEmean)                  0.02      0.01     0.00     0.04 1.00     6111
# sd(TRAITmean)                  0.01      0.01     0.00     0.03 1.00     9034
# sd(STATEdiff)                  0.03      0.01     0.01     0.06 1.00     7048
# sd(TRAITdiff)                  0.01      0.01     0.00     0.03 1.00     8654
# sd(BPdiff_stdz)                0.04      0.01     0.02     0.07 1.00     8588
# cor(Intercept,STATEmean)       0.04      0.36    -0.65     0.71 1.00    17746
# cor(Intercept,TRAITmean)      -0.01      0.37    -0.71     0.69 1.00    21593
# cor(STATEmean,TRAITmean)      -0.09      0.38    -0.77     0.66 1.00    16438
# cor(Intercept,STATEdiff)       0.50      0.26    -0.10     0.88 1.00     9894
# cor(STATEmean,STATEdiff)      -0.07      0.36    -0.73     0.63 1.00     7665
# cor(TRAITmean,STATEdiff)       0.05      0.37    -0.67     0.73 1.00     8301
# cor(Intercept,TRAITdiff)       0.14      0.37    -0.60     0.78 1.00    18536
# cor(STATEmean,TRAITdiff)      -0.02      0.38    -0.71     0.70 1.00    15750
# cor(TRAITmean,TRAITdiff)       0.05      0.38    -0.67     0.74 1.00    13297
# cor(STATEdiff,TRAITdiff)       0.14      0.37    -0.61     0.77 1.00    17077
# cor(Intercept,BPdiff_stdz)    -0.35      0.26    -0.79     0.20 1.00     8775
# cor(STATEmean,BPdiff_stdz)    -0.22      0.36    -0.80     0.54 1.00     4788
# cor(TRAITmean,BPdiff_stdz)     0.03      0.37    -0.68     0.72 1.00     6190
# cor(STATEdiff,BPdiff_stdz)     0.02      0.30    -0.57     0.60 1.00    11340
# cor(TRAITdiff,BPdiff_stdz)     0.06      0.36    -0.65     0.72 1.00     9750
#                            Tail_ESS
# df                             1064
# sd(Intercept)                  8578
# sd(STATEmean)                  7709
# sd(TRAITmean)                  8374
# sd(STATEdiff)                  5182
# sd(TRAITdiff)                  7508
# sd(BPdiff_stdz)                9283
# cor(Intercept,STATEmean)      13917
# cor(Intercept,TRAITmean)      13602
# cor(STATEmean,TRAITmean)      14410
# cor(Intercept,STATEdiff)      12488
# cor(STATEmean,STATEdiff)      10289
# cor(TRAITmean,STATEdiff)      11830
# cor(Intercept,TRAITdiff)      14480
# cor(STATEmean,TRAITdiff)      14274
# cor(TRAITmean,TRAITdiff)      15113
# cor(STATEdiff,TRAITdiff)      15470
# cor(Intercept,BPdiff_stdz)    10823
# cor(STATEmean,BPdiff_stdz)     7866
# cor(TRAITmean,BPdiff_stdz)    11856
# cor(STATEdiff,BPdiff_stdz)    13635
# cor(TRAITdiff,BPdiff_stdz)    14135
#
# ~Subj (Number of levels: 61)
#               Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS Tail_ESS
# df               35.47     19.39     9.03    83.58 1.02      360      565
# sd(Intercept)     0.15      0.02     0.11     0.18 1.00     4610     9770
#
# Population-Level Effects:
#             Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS Tail_ESS
# Intercept       0.02      0.02    -0.02     0.07 1.00     4557     7885
# STATEmean       0.01      0.03    -0.05     0.07 1.00     4337     7622
# TRAITmean      -0.01      0.03    -0.06     0.05 1.00     4281     7523
# STATEdiff      -0.00      0.02    -0.05     0.04 1.00     5438     8900
# TRAITdiff      -0.00      0.02    -0.05     0.04 1.00     4999     8359
# BPdiff_stdz     0.01      0.02    -0.04     0.06 1.00     4938     8416
#
# Family Specific Parameters:
#       Estimate Est.Error l-95% CI u-95% CI Rhat Bulk_ESS Tail_ESS
# sigma     0.24      0.01     0.23     0.26 1.00    13770    14611
# nu        3.67      0.41     2.96     4.55 1.00    14778    13754
#
# Samples were drawn using sampling(NUTS). For each parameter, Bulk_ESS
# and Tail_ESS are effective sample size measures, and Rhat is the potential
# scale reduction factor on split chains (at convergence, Rhat = 1).

# %%
# Extract posteriors for fixed (aa) and random effects (bb)
aa <- fixef(fm, summary = FALSE)/SCALE # Population-Level Estimates
bb <- lapply(ranef(fm, summary = FALSE), `/`, SCALE) # Extract Group-Level (or random-effect)

# %% [markdown]
# ### Functions

# %%
# Following functions add the "the poaterior of the global intercept with the intercept posterior of each roi"
# bb[['ROI']][,,tm] is a matrix with columns containing posteriors for every ROI
# aa[,tm] is a single column posterior for the global intercept.
psROI <- function(aa, bb, tm) {
  ps <- apply(bb[['ROI']][,,tm], 2, '+', aa[,tm])
  return(ps)
}
# apply(X,axis,func,..)
# check help for apply (?apply)


# compute P+
cnt <- function(x, ns) return(sum(x>0)/ns)
# summary for ROIs: nd - number of digits to output
sumROI <- function(R0, ns, nd) {
  hubs <- data.frame(cbind(apply(R0, 2, mean), apply(R0, 2, sd), apply(R0, 2, cnt, ns), t(apply(R0, 2, quantile, 
      probs=c(0.025, 0.05, 0.5, 0.95, 0.975)))))
  names(hubs) <- c('mean', 'SD', 'P+', '2.5%', '5%', '50%', '95%', '97.5%')
  return(round(hubs,nd))
}

################################# conventional GLM ############################################
sumGLM <- function(ll, tm, nR, DF, nd) {
   th <- qt(c(0.025, 0.05, 0.5, 0.95, 0.975), DF)
   rr <- matrix(0, nrow = nR, ncol = 8, dimnames=list(levels(dataTable$ROI), c('mean', 'SD', '2-sided-p', '2.5%', '5%', '50%', '95%', '97.5%')))
   rownames(rr) <- levels(dataTable$ROI)
   if(tm == 'Intercept') tm <- '(Intercept)'
   for(ii in 1:nR) {
     u1 <- ll[[ii]]$coefficients[tm,1] # mean
     u2 <- ll[[ii]]$coefficients[tm,2] # sd
     u3 <- ll[[ii]]$coefficients[tm,4] # 2-sided p
     rr[ii,] <- round(c(u1, u2, u3, u1+u2*th),nd)
   } 
   return(rr)
}

################################# function to plot posteriors ##################################
plotPDP <- function(ps0,gg_brm,gg_glm){
rois <- colnames(ps0) # Global intercept + ROI intercepts
nobs=dim(ps0)[1] # gets number of rows and assigns it to nobj

# initialize a single column dataframe with number of row equal to number of rois
data_stats = data.frame(1:length(rois)) 
data_stats$ROI <- rois # adds an ROI column with roi names

#data_stats$mean <- colMeans(data)
data_stats$brmMean <- gg_brm$mean # Adds a brmMean columns
data_stats$glmMean <- gg_glm$mean # Adds a brmMean columns

# gets proportion of the posterior greater than 0 for each roi
data_stats$P <- colSums(ps0 > 0)/nobs 
# gets proportion of the posterior less than 0
#data_stats$Pn <- 1 - data_stats$P
data_stats$Pn <- data_stats$P
for (i in 1:length(rois)) {
  if (data_stats$P[i]<.5){data_stats$Pn[i]=1-data_stats$P[i]}
}

# this will order the distributions correctly
#data_stats <- data_stats[order(data_stats$brmMean),]
data_stats <- data_stats[order(data_stats$P),]

data_trans <- as.data.frame(t(as.matrix(ps0)))
data_trans <- tibble::rownames_to_column(data_trans, "ROI")
data_trans$X <- 1:nrow(data_trans)

# merge values & stats into one table by ROI
data_merge <- merge(data_stats, data_trans, by = "ROI")
data_merge <- data_merge[order(data_merge$X),]

# Transform data into long form
# Melt dataframe by ROI
library(data.table)

data_long <- melt(data_trans, id=c("ROI","X"))
data_long <- data_long[order(data_long$X),]

# This is incredibly clunky, but for the sake of time adding stats by ensuring orders are all the same and repeating each value 2000 times... Tried a few different methods with no success for some reason. 

data_long$brmMean <- rep(data_merge$brmMean, each = nobs)
data_long$glmMean <- rep(data_merge$glmMean, each = nobs)
data_long$P <- rep(data_merge$P, each =nobs)
data_long$Pn <- rep(data_merge$Pn, each =nobs)

# set your labels here so you don't have to change within the plot below: 
format(round(1, 2), nsmall = 2)

y.axis.labs <- format(round(data_stats$P,3), nsmall = 2)                        # y axis labels
sec.y.axis.labs <- data_stats$ROI                             # second y axis labels (probabilities)

 # X AXIS LABELS NEED TO CHANGE TO CORRESPOND TO DATA SET! UNCOMMENT WHICHEVER MATCHES

# Uncomment for THREAT
x.axis.labs <- c( "control > uncontrol", "0", "uncontrol > control")                 # x axis labels  THREAT
x.labs.pos <- c(-0.2, 0, 0.2)                                             # x axis position THREAT

#graph.title <- data.name                                   # graph title 
legend.title <- "Probability"                              # legend title
y.axis.title <- NULL                                       # for now ...
x.axis.title <- NULL                                       # for now...

# GRAPH DATA
library(repr)
options(repr.plot.width=10,repr.plot.height=8)

dataset <- data_long
x.values <- data_long$value                               # x values
y.values <- data_long$ROI                                 # y values
y.values.RO <- data_long$value                            # values to reorder Y by
distrib.fill <- data_long$Pn                              # fill graph with probabilities
group <- data_long$ROI

# Other aspects
gradient.colors <- c("yellow","#C9182B","#41245C")        # change gradient colors here (currently, yellow - purple)
label.size <- 16                                         # adjust ROI and probability y-axis font size
title.size <- 32                                         # adjust graph title size 
x.axis.size <- 16                                        # adjust x-axis label sizes

# here is where you can change information about the graph and add other characteristics using ggplot and ggridges


ggplot(dataset, aes(x = x.values, y = as.numeric(reorder(y.values, y.values.RO)), 
                    fill = distrib.fill, group = group)) +                      # scale = spacing, alpha = transparency
  coord_cartesian(xlim = c(-0.25, 0.25)) +
  stat_density_ridges(quantile_lines = TRUE, 
                      quantiles = 2, 
                      alpha = .95, 
                      scale = 1,
                      color = "black",
                      size = .35
                     ) +
    geom_segment(aes(x = glmMean, xend = glmMean, y = as.numeric(reorder(y.values, y.values.RO)),
                                      yend = as.numeric(reorder(y.values, y.values.RO))+0.9), color = "red") +           # divide into two quantiles (show mean)
  geom_vline(xintercept = 0, linetype="solid",color = "black",alpha = .95, size = .45) +    #create line at X = 0
  scale_fill_gradientn(colors = viridis_pal(direction = 1, option = "inferno")(20),                         # set gradient
                       limits = c(.85,1),                                # which probabilites matter?
                       na.value = "#909497",                                # if not in limits, gray out
                       name = legend.title) +                            # name legend
  scale_y_continuous(breaks = 1:length(rois),                            # A VERY HACK-Y WAY TO HAVE TWO Y AXES W DISCRETE DATA
                     expand = c(0,0),
                     labels = y.axis.labs,                               # Trick ggplot into thinking data is continuous...
                     sec.axis = sec_axis(~.,                             # Second axis to show probabilities
                                         breaks = 1:length(rois),
                                         labels = sec.y.axis.labs)) +
  #theme_ridges(font_size = label.size, grid = TRUE, center_axis_labels = TRUE) +  # theme info
  #ggtitle(graph.title)+ 
  #theme_bw() +# graph title
 #theme_ridges(grid = FALSE) + 
  theme(   
    panel.background = element_blank(),
    #legend.position = "none",
    #panel.grid.major.y = element_line(color = "grey"), 
    plot.title = element_text(hjust = 0.5, size = title.size),            # plot title size and position
    axis.text.y = element_text(size=label.size),                               # y-axis text size
    axis.line.x = element_line(color = "gray"),
    axis.text.y.right = element_text(size = label.size),                  # y-axis info for right axis
    axis.text.x = element_text(size = x.axis.size),
    #plot.margin = unit(c(0,0,0,0), "cm"),
    axis.ticks.x = element_blank(),
    axis.ticks.y = element_blank(),
    legend.title.align = 5)+
  guides(shape = guide_legend(label.position = "bottom",
                              title.positon = "bottom",
                              title.vjust = 0.4)) +          
  labs(
    x = NULL,                                                         # Add or not add X and Y labels
    y = NULL) +
  scale_x_continuous(breaks = x.labs.pos, labels = c(x.axis.labs))
}

# %% [markdown]
# # **2. BML and GLM Summaries with Posterior Plots**

# %%
# for Intercept and quantitative variables
ii = 1
cat(sprintf('===== Summary of region effects for %s (RBA results) =====', EOIq[ii]), sep = '\n', append=TRUE)
ps0 <- psROI(aa, bb, EOIq[ii])
gg_brm <- sumROI(ps0, ns, nfigs)
#gg_brm$ROI <- factor(rownames(gg_brm))
cat(capture.output(gg_brm), sep = '\n', append=TRUE)

cat(sprintf('=================================================================================================================='),sep='\n')
cat(sprintf('===== Summary of region effects under GLM for %s (for reference only): no adjustment for multiplicity =====', EOIq[ii]),sep = '\n', append=TRUE)
mm <- list()
GLM <- as.formula(paste('Y ~ ',mod))
if(SCALE!=1) dataTable$Y <- (dataTable$Y)/SCALE  # scale back for GLM
for(kk in levels(dataTable$ROI)) mm[[kk]] = lm(GLM, data=dataTable[dataTable$ROI==kk,])
nn <- lapply(mm, summary)
ll <- lapply(nn, `[`, 'coefficients')
gg_glm <- sumGLM(ll, EOIq[ii], nR, nn[[ii]]$df, nfigs)
gg_glm = as.data.frame(gg_glm)
cat(capture.output(gg_glm),sep = '\n', append=TRUE)

cat(sprintf('======================================== Posteriors for %s ====================================================',EOIq[ii],sep='\n'))
plotPDP(ps0,gg_brm,gg_glm)
# Out:
# ===== Summary of region effects for Intercept (RBA results) =====
#                                              mean     SD     P+    2.5%      5%
# L aMCC                                     0.0188 0.0338 0.7143 -0.0484 -0.0376
# L Amygdala (BLBM)                          0.0153 0.0347 0.6725 -0.0532 -0.0427
# L Amygdala (CeME)                          0.0484 0.0387 0.8994 -0.0252 -0.0135
# L Anterior dorsal insula                   0.0751 0.0335 0.9902  0.0112  0.0209
# L Anterior hippocampus                     0.0040 0.0333 0.5513 -0.0631 -0.0514
# L Anterior ventral insula (anterior pole)  0.0097 0.0325 0.6213 -0.0540 -0.0443
# L BST                                      0.1313 0.0464 0.9990  0.0430  0.0576
# L Mid posterior insula                    -0.0013 0.0324 0.4874 -0.0658 -0.0552
# L PAG                                      0.0250 0.0344 0.7687 -0.0426 -0.0316
# L Thalamus (emoproxI shock intersection)   0.0487 0.0329 0.9320 -0.0150 -0.0052
# PCC (1)                                   -0.0217 0.0381 0.2875 -0.0982 -0.0861
# PCC (2)                                   -0.0387 0.0428 0.1820 -0.1268 -0.1111
# R  BST                                     0.1143 0.0454 0.9960  0.0285  0.0411
# R aMCC                                     0.0069 0.0372 0.5730 -0.0655 -0.0534
# R Amygdala (BLBM)                          0.0522 0.0367 0.9260 -0.0181 -0.0069
# R Amygdala (CeME)                          0.0325 0.0365 0.8152 -0.0386 -0.0270
# R Anterior dorsal insula                   0.0413 0.0326 0.9004 -0.0219 -0.0117
# R Anterior hippocampus                     0.0020 0.0349 0.5278 -0.0677 -0.0561
# R Anterior ventral insula (anterior pole)  0.0245 0.0333 0.7710 -0.0409 -0.0307
# R Mid posterior insula                     0.0003 0.0330 0.5068 -0.0668 -0.0549
# R PAG                                      0.0150 0.0344 0.6684 -0.0525 -0.0414
# R Thalamus (emoproxI shock intersection)   0.0381 0.0325 0.8816 -0.0252 -0.0145
# vmPFC (from out lab)                      -0.0175 0.0349 0.3124 -0.0879 -0.0764
# vmPFC (new 5mm sphere from Hartley paper) -0.0205 0.0336 0.2726 -0.0872 -0.0764
#                                               50%    95%  97.5%
# L aMCC                                     0.0193 0.0737 0.0848
# L Amygdala (BLBM)                          0.0154 0.0721 0.0834
# L Amygdala (CeME)                          0.0473 0.1137 0.1275
# L Anterior dorsal insula                   0.0749 0.1307 0.1418
# L Anterior hippocampus                     0.0043 0.0576 0.0682
# L Anterior ventral insula (anterior pole)  0.0098 0.0630 0.0728
# L BST                                      0.1300 0.2105 0.2260
# L Mid posterior insula                    -0.0010 0.0517 0.0620
# L PAG                                      0.0252 0.0814 0.0930
# L Thalamus (emoproxI shock intersection)   0.0482 0.1030 0.1135
# PCC (1)                                   -0.0210 0.0393 0.0506
# PCC (2)                                   -0.0374 0.0291 0.0411
# R  BST                                     0.1137 0.1905 0.2060
# R aMCC                                     0.0067 0.0689 0.0807
# R Amygdala (BLBM)                          0.0516 0.1135 0.1261
# R Amygdala (CeME)                          0.0324 0.0928 0.1047
# R Anterior dorsal insula                   0.0411 0.0957 0.1060
# R Anterior hippocampus                     0.0025 0.0581 0.0683
# R Anterior ventral insula (anterior pole)  0.0246 0.0793 0.0897
# R Mid posterior insula                     0.0006 0.0542 0.0646
# R PAG                                      0.0149 0.0709 0.0813
# R Thalamus (emoproxI shock intersection)   0.0380 0.0917 0.1025
# vmPFC (from out lab)                      -0.0166 0.0389 0.0490
# vmPFC (new 5mm sphere from Hartley paper) -0.0200 0.0337 0.0447
# ==================================================================================================================
# ===== Summary of region effects under GLM for Intercept (for reference only): no adjustment for multiplicity =====
#                                              mean     SD 2-sided-p    2.5%
# L aMCC                                     0.0422 0.0505    0.4077 -0.0815
# L Amygdala (BLBM)                          0.1000 0.0685    0.1498 -0.0675
# L Amygdala (CeME)                          0.0740 0.0747    0.3258 -0.1087
# L Anterior dorsal insula                   0.1001 0.0279    0.0007  0.0318
# L Anterior hippocampus                    -0.0225 0.0374    0.5497 -0.1139
# L Anterior ventral insula (anterior pole)  0.0103 0.0235    0.6632 -0.0472
# L BST                                      0.1901 0.0643    0.0046  0.0327
# L Mid posterior insula                    -0.0204 0.0266    0.4460 -0.0854
# L PAG                                      0.0178 0.0462    0.7017 -0.0952
# L Thalamus (emoproxI shock intersection)   0.0562 0.0341    0.1049 -0.0272
# PCC (1)                                   -0.0464 0.0625    0.4607 -0.1993
# PCC (2)                                   -0.1243 0.0741    0.0991 -0.3057
# R  BST                                     0.1292 0.0563    0.0257 -0.0086
# R aMCC                                     0.0072 0.0534    0.8931 -0.1235
# R Amygdala (BLBM)                          0.0614 0.0574    0.2899 -0.0792
# R Amygdala (CeME)                          0.0163 0.0768    0.8328 -0.1716
# R Anterior dorsal insula                   0.0638 0.0286    0.0295 -0.0061
# R Anterior hippocampus                    -0.0140 0.0431    0.7464 -0.1194
# R Anterior ventral insula (anterior pole)  0.0309 0.0351    0.3831 -0.0551
# R Mid posterior insula                    -0.0079 0.0329    0.8112 -0.0883
# R PAG                                     -0.0097 0.0546    0.8589 -0.1433
# R Thalamus (emoproxI shock intersection)   0.0400 0.0357    0.2666 -0.0473
# vmPFC (from out lab)                      -0.0397 0.0493    0.4248 -0.1604
# vmPFC (new 5mm sphere from Hartley paper) -0.0470 0.0286    0.1066 -0.1170
#                                                5%     50%    95%  97.5%
# L aMCC                                    -0.0424  0.0422 0.1404 0.1434
# L Amygdala (BLBM)                         -0.0145  0.1000 0.2330 0.2372
# L Amygdala (CeME)                         -0.0509  0.0740 0.2191 0.2236
# L Anterior dorsal insula                   0.0534  0.1001 0.1543 0.1560
# L Anterior hippocampus                    -0.0850 -0.0225 0.0501 0.0524
# L Anterior ventral insula (anterior pole) -0.0290  0.0103 0.0559 0.0573
# L BST                                      0.0825  0.1901 0.3151 0.3190
# L Mid posterior insula                    -0.0648 -0.0204 0.0312 0.0328
# L PAG                                     -0.0595  0.0178 0.1075 0.1103
# L Thalamus (emoproxI shock intersection)  -0.0008  0.0562 0.1224 0.1245
# PCC (1)                                   -0.1510 -0.0464 0.0750 0.0788
# PCC (2)                                   -0.2484 -0.1243 0.0197 0.0242
# R  BST                                     0.0349  0.1292 0.2386 0.2421
# R aMCC                                    -0.0822  0.0072 0.1111 0.1143
# R Amygdala (BLBM)                         -0.0347  0.0614 0.1730 0.1765
# R Amygdala (CeME)                         -0.1122  0.0163 0.1655 0.1702
# R Anterior dorsal insula                   0.0160  0.0638 0.1194 0.1211
# R Anterior hippocampus                    -0.0861 -0.0140 0.0697 0.0723
# R Anterior ventral insula (anterior pole) -0.0279  0.0309 0.0992 0.1013
# R Mid posterior insula                    -0.0628 -0.0079 0.0560 0.0580
# R PAG                                     -0.1010 -0.0097 0.0963 0.0996
# R Thalamus (emoproxI shock intersection)  -0.0196  0.0400 0.1094 0.1115
# vmPFC (from out lab)                      -0.1222 -0.0397 0.0562 0.0592
# vmPFC (new 5mm sphere from Hartley paper) -0.0948 -0.0470 0.0087 0.0104
# ======================================== Posteriors for Intercept ====================================================
# Warning message in melt(data_trans, id = c("ROI", "X")):
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(data_trans). In the next version, this warning will become an error.”
# Picking joint bandwidth of 0.00443
# plot without title

# %% [markdown]
# Red vertical lines: GLM

# %%
ii = 6
cat(sprintf('===== Summary of region effects for %s (RBA results) =====', EOIq[ii]), sep = '\n', append=TRUE)
ps0 <- psROI(aa, bb, EOIq[ii])
gg_brm <- sumROI(ps0, ns, nfigs)
#gg_brm$ROI <- factor(rownames(gg_brm))
cat(capture.output(gg_brm), sep = '\n', append=TRUE)

cat(sprintf('=================================================================================================================='),sep='\n')
cat(sprintf('===== Summary of region effects under GLM for %s (for reference only): no adjustment for multiplicity =====', EOIq[ii]),sep = '\n', append=TRUE)
mm <- list()
GLM <- as.formula(paste('Y ~ ',mod))
if(SCALE!=1) dataTable$Y <- (dataTable$Y)/SCALE  # scale back for GLM
for(kk in levels(dataTable$ROI)) mm[[kk]] = lm(GLM, data=dataTable[dataTable$ROI==kk,])
nn <- lapply(mm, summary)
ll <- lapply(nn, `[`, 'coefficients')
gg_glm <- sumGLM(ll, EOIq[ii], nR, nn[[ii]]$df, nfigs)
gg_glm = as.data.frame(gg_glm)
cat(capture.output(gg_glm),sep = '\n', append=TRUE)

cat(sprintf('======================================== Posteriors for %s ====================================================',EOIq[ii],sep='\n'))
plotPDP(ps0,gg_brm,gg_glm)
# Out:
# ===== Summary of region effects for BPdiff_stdz (RBA results) =====
#                                              mean     SD     P+    2.5%      5%
# L aMCC                                     0.0169 0.0343 0.6888 -0.0502 -0.0392
# L Amygdala (BLBM)                          0.0370 0.0354 0.8558 -0.0305 -0.0200
# L Amygdala (CeME)                          0.0123 0.0368 0.6282 -0.0596 -0.0477
# L Anterior dorsal insula                   0.0007 0.0329 0.5104 -0.0647 -0.0540
# L Anterior hippocampus                     0.0270 0.0333 0.7948 -0.0380 -0.0266
# L Anterior ventral insula (anterior pole) -0.0043 0.0332 0.4520 -0.0695 -0.0597
# L BST                                     -0.0553 0.0475 0.1180 -0.1536 -0.1364
# L Mid posterior insula                     0.0405 0.0326 0.8958 -0.0229 -0.0126
# L PAG                                     -0.0007 0.0338 0.4964 -0.0682 -0.0566
# L Thalamus (emoproxI shock intersection)  -0.0030 0.0331 0.4648 -0.0686 -0.0575
# PCC (1)                                   -0.0040 0.0381 0.4648 -0.0797 -0.0670
# PCC (2)                                   -0.0111 0.0414 0.4029 -0.0942 -0.0809
# R  BST                                    -0.0883 0.0486 0.0296 -0.1863 -0.1698
# R aMCC                                     0.0752 0.0412 0.9726 -0.0011  0.0094
# R Amygdala (BLBM)                          0.0506 0.0365 0.9226 -0.0177 -0.0073
# R Amygdala (CeME)                          0.0399 0.0365 0.8640 -0.0285 -0.0181
# R Anterior dorsal insula                  -0.0054 0.0329 0.4426 -0.0722 -0.0604
# R Anterior hippocampus                     0.0291 0.0338 0.8061 -0.0366 -0.0259
# R Anterior ventral insula (anterior pole) -0.0185 0.0342 0.3000 -0.0876 -0.0760
# R Mid posterior insula                     0.0368 0.0326 0.8701 -0.0259 -0.0162
# R PAG                                      0.0075 0.0345 0.5903 -0.0604 -0.0494
# R Thalamus (emoproxI shock intersection)   0.0024 0.0335 0.5302 -0.0636 -0.0530
# vmPFC (from out lab)                       0.0277 0.0335 0.7984 -0.0378 -0.0270
# vmPFC (new 5mm sphere from Hartley paper)  0.0182 0.0335 0.7086 -0.0476 -0.0375
#                                               50%     95%  97.5%
# L aMCC                                     0.0166  0.0737 0.0852
# L Amygdala (BLBM)                          0.0358  0.0966 0.1093
# L Amygdala (CeME)                          0.0120  0.0733 0.0863
# L Anterior dorsal insula                   0.0008  0.0538 0.0652
# L Anterior hippocampus                     0.0265  0.0821 0.0933
# L Anterior ventral insula (anterior pole) -0.0040  0.0504 0.0602
# L BST                                     -0.0531  0.0195 0.0324
# L Mid posterior insula                     0.0402  0.0944 0.1050
# L PAG                                     -0.0003  0.0542 0.0645
# L Thalamus (emoproxI shock intersection)  -0.0030  0.0508 0.0617
# PCC (1)                                   -0.0034  0.0577 0.0683
# PCC (2)                                   -0.0100  0.0550 0.0675
# R  BST                                    -0.0874 -0.0098 0.0033
# R aMCC                                     0.0740  0.1443 0.1580
# R Amygdala (BLBM)                          0.0497  0.1122 0.1251
# R Amygdala (CeME)                          0.0391  0.1014 0.1139
# R Anterior dorsal insula                  -0.0046  0.0476 0.0581
# R Anterior hippocampus                     0.0288  0.0846 0.0957
# R Anterior ventral insula (anterior pole) -0.0177  0.0359 0.0466
# R Mid posterior insula                     0.0368  0.0910 0.1020
# R PAG                                      0.0079  0.0639 0.0756
# R Thalamus (emoproxI shock intersection)   0.0027  0.0574 0.0683
# vmPFC (from out lab)                       0.0274  0.0838 0.0946
# vmPFC (new 5mm sphere from Hartley paper)  0.0180  0.0735 0.0842
# ==================================================================================================================
# ===== Summary of region effects under GLM for BPdiff_stdz (for reference only): no adjustment for multiplicity =====
#                                              mean     SD 2-sided-p    2.5%
# L aMCC                                     0.0067 0.0536    0.9007 -0.1244
# L Amygdala (BLBM)                          0.0514 0.0726    0.4822 -0.1263
# L Amygdala (CeME)                         -0.0111 0.0792    0.8894 -0.2048
# L Anterior dorsal insula                  -0.0105 0.0296    0.7241 -0.0829
# L Anterior hippocampus                     0.0360 0.0396    0.3680 -0.0610
# L Anterior ventral insula (anterior pole) -0.0114 0.0249    0.6500 -0.0723
# L BST                                     -0.1316 0.0682    0.0589 -0.2985
# L Mid posterior insula                     0.0437 0.0282    0.1268 -0.0252
# L PAG                                     -0.0066 0.0490    0.8926 -0.1265
# L Thalamus (emoproxI shock intersection)  -0.0094 0.0361    0.7960 -0.0978
# PCC (1)                                   -0.0261 0.0663    0.6956 -0.1882
# PCC (2)                                   -0.0455 0.0786    0.5652 -0.2378
# R  BST                                    -0.1666 0.0597    0.0073 -0.3127
# R aMCC                                     0.0943 0.0567    0.1016 -0.0443
# R Amygdala (BLBM)                          0.1056 0.0609    0.0884 -0.0434
# R Amygdala (CeME)                          0.1146 0.0814    0.1650 -0.0847
# R Anterior dorsal insula                  -0.0305 0.0303    0.3191 -0.1046
# R Anterior hippocampus                     0.0402 0.0457    0.3826 -0.0716
# R Anterior ventral insula (anterior pole) -0.0459 0.0373    0.2231 -0.1371
# R Mid posterior insula                     0.0373 0.0348    0.2894 -0.0480
# R PAG                                     -0.0225 0.0579    0.6986 -0.1641
# R Thalamus (emoproxI shock intersection)  -0.0080 0.0378    0.8327 -0.1006
# vmPFC (from out lab)                       0.0729 0.0523    0.1690 -0.0551
# vmPFC (new 5mm sphere from Hartley paper)  0.0189 0.0303    0.5352 -0.0553
#                                                5%     50%     95%   97.5%
# L aMCC                                    -0.0829  0.0067  0.1108  0.1141
# L Amygdala (BLBM)                         -0.0701  0.0514  0.1924  0.1969
# L Amygdala (CeME)                         -0.1435 -0.0111  0.1428  0.1476
# L Anterior dorsal insula                  -0.0600 -0.0105  0.0470  0.0488
# L Anterior hippocampus                    -0.0303  0.0360  0.1130  0.1154
# L Anterior ventral insula (anterior pole) -0.0530 -0.0114  0.0370  0.0385
# L BST                                     -0.2457 -0.1316  0.0010  0.0051
# L Mid posterior insula                    -0.0035  0.0437  0.0984  0.1001
# L PAG                                     -0.0886 -0.0066  0.0885  0.0915
# L Thalamus (emoproxI shock intersection)  -0.0698 -0.0094  0.0608  0.0630
# PCC (1)                                   -0.1369 -0.0261  0.1027  0.1067
# PCC (2)                                   -0.1770 -0.0455  0.1073  0.1120
# R  BST                                    -0.2665 -0.1666 -0.0505 -0.0469
# R aMCC                                    -0.0005  0.0943  0.2045  0.2079
# R Amygdala (BLBM)                          0.0037  0.1056  0.2240  0.2277
# R Amygdala (CeME)                         -0.0216  0.1146  0.2728  0.2777
# R Anterior dorsal insula                  -0.0811 -0.0305  0.0284  0.0303
# R Anterior hippocampus                    -0.0362  0.0402  0.1289  0.1317
# R Anterior ventral insula (anterior pole) -0.1083 -0.0459  0.0265  0.0288
# R Mid posterior insula                    -0.0210  0.0373  0.1050  0.1071
# R PAG                                     -0.1193 -0.0225  0.0899  0.0934
# R Thalamus (emoproxI shock intersection)  -0.0713 -0.0080  0.0655  0.0678
# vmPFC (from out lab)                      -0.0146  0.0729  0.1746  0.1778
# vmPFC (new 5mm sphere from Hartley paper) -0.0318  0.0189  0.0779  0.0798
# ======================================== Posteriors for BPdiff_stdz ====================================================
# Warning message in melt(data_trans, id = c("ROI", "X")):
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(data_trans). In the next version, this warning will become an error.”
# Picking joint bandwidth of 0.00445
# plot without title

# %%
ii = 2
cat(sprintf('===== Summary of region effects for %s (RBA results) =====', EOIq[ii]), sep = '\n', append=TRUE)
ps0 <- psROI(aa, bb, EOIq[ii])
gg_brm <- sumROI(ps0, ns, nfigs)
#gg_brm$ROI <- factor(rownames(gg_brm))
cat(capture.output(gg_brm), sep = '\n', append=TRUE)

cat(sprintf('=================================================================================================================='),sep='\n')
cat(sprintf('===== Summary of region effects under GLM for %s (for reference only): no adjustment for multiplicity =====', EOIq[ii]),sep = '\n', append=TRUE)
mm <- list()
GLM <- as.formula(paste('Y ~ ',mod))
if(SCALE!=1) dataTable$Y <- (dataTable$Y)/SCALE  # scale back for GLM
for(kk in levels(dataTable$ROI)) mm[[kk]] = lm(GLM, data=dataTable[dataTable$ROI==kk,])
nn <- lapply(mm, summary)
ll <- lapply(nn, `[`, 'coefficients')
gg_glm <- sumGLM(ll, EOIq[ii], nR, nn[[ii]]$df, nfigs)
gg_glm = as.data.frame(gg_glm)
cat(capture.output(gg_glm),sep = '\n', append=TRUE)

cat(sprintf('======================================== Posteriors for %s ====================================================',EOIq[ii],sep='\n'))
plotPDP(ps0,gg_brm,gg_glm)
# Out:
# ===== Summary of region effects for STATEmean (RBA results) =====
#                                              mean     SD     P+    2.5%      5%
# L aMCC                                     0.0093 0.0318 0.6141 -0.0531 -0.0430
# L Amygdala (BLBM)                          0.0064 0.0318 0.5826 -0.0569 -0.0462
# L Amygdala (CeME)                          0.0113 0.0327 0.6380 -0.0532 -0.0419
# L Anterior dorsal insula                   0.0040 0.0323 0.5552 -0.0617 -0.0507
# L Anterior hippocampus                     0.0090 0.0317 0.6154 -0.0529 -0.0431
# L Anterior ventral insula (anterior pole)  0.0155 0.0319 0.6842 -0.0458 -0.0358
# L BST                                      0.0223 0.0363 0.7303 -0.0452 -0.0350
# L Mid posterior insula                     0.0035 0.0321 0.5519 -0.0607 -0.0499
# L PAG                                      0.0123 0.0316 0.6510 -0.0497 -0.0394
# L Thalamus (emoproxI shock intersection)   0.0080 0.0315 0.6046 -0.0548 -0.0442
# PCC (1)                                    0.0195 0.0347 0.7110 -0.0455 -0.0353
# PCC (2)                                    0.0141 0.0338 0.6630 -0.0519 -0.0404
# R  BST                                     0.0285 0.0393 0.7648 -0.0413 -0.0304
# R aMCC                                    -0.0030 0.0347 0.4790 -0.0758 -0.0622
# R Amygdala (BLBM)                          0.0033 0.0329 0.5466 -0.0628 -0.0522
# R Amygdala (CeME)                          0.0059 0.0326 0.5778 -0.0594 -0.0484
# R Anterior dorsal insula                   0.0074 0.0315 0.5973 -0.0555 -0.0445
# R Anterior hippocampus                     0.0091 0.0319 0.6112 -0.0534 -0.0427
# R Anterior ventral insula (anterior pole)  0.0174 0.0325 0.7068 -0.0449 -0.0348
# R Mid posterior insula                     0.0031 0.0322 0.5441 -0.0620 -0.0505
# R PAG                                      0.0081 0.0314 0.6070 -0.0537 -0.0433
# R Thalamus (emoproxI shock intersection)   0.0051 0.0319 0.5717 -0.0602 -0.0485
# vmPFC (from out lab)                       0.0173 0.0329 0.6960 -0.0447 -0.0350
# vmPFC (new 5mm sphere from Hartley paper)  0.0100 0.0317 0.6226 -0.0521 -0.0411
#                                               50%    95%  97.5%
# L aMCC                                     0.0093 0.0613 0.0716
# L Amygdala (BLBM)                          0.0062 0.0580 0.0681
# L Amygdala (CeME)                          0.0111 0.0652 0.0769
# L Anterior dorsal insula                   0.0045 0.0559 0.0666
# L Anterior hippocampus                     0.0089 0.0611 0.0713
# L Anterior ventral insula (anterior pole)  0.0150 0.0688 0.0796
# L BST                                      0.0211 0.0839 0.0985
# L Mid posterior insula                     0.0040 0.0550 0.0653
# L PAG                                      0.0122 0.0640 0.0744
# L Thalamus (emoproxI shock intersection)   0.0083 0.0594 0.0691
# PCC (1)                                    0.0183 0.0780 0.0916
# PCC (2)                                    0.0134 0.0703 0.0828
# R  BST                                     0.0256 0.0978 0.1135
# R aMCC                                    -0.0017 0.0515 0.0608
# R Amygdala (BLBM)                          0.0039 0.0557 0.0661
# R Amygdala (CeME)                          0.0059 0.0583 0.0693
# R Anterior dorsal insula                   0.0076 0.0585 0.0684
# R Anterior hippocampus                     0.0089 0.0616 0.0723
# R Anterior ventral insula (anterior pole)  0.0168 0.0711 0.0835
# R Mid posterior insula                     0.0034 0.0550 0.0655
# R PAG                                      0.0080 0.0595 0.0696
# R Thalamus (emoproxI shock intersection)   0.0057 0.0562 0.0661
# vmPFC (from out lab)                       0.0163 0.0726 0.0845
# vmPFC (new 5mm sphere from Hartley paper)  0.0096 0.0618 0.0723
# ==================================================================================================================
# ===== Summary of region effects under GLM for STATEmean (for reference only): no adjustment for multiplicity =====
#                                              mean     SD 2-sided-p    2.5%
# L aMCC                                    -0.0752 0.0687    0.2779 -0.2433
# L Amygdala (BLBM)                          0.0128 0.0930    0.8911 -0.2148
# L Amygdala (CeME)                          0.0850 0.1014    0.4060 -0.1633
# L Anterior dorsal insula                  -0.0343 0.0379    0.3700 -0.1270
# L Anterior hippocampus                     0.0081 0.0508    0.8739 -0.1162
# L Anterior ventral insula (anterior pole)  0.0215 0.0319    0.5031 -0.0566
# L BST                                     -0.0223 0.0874    0.7996 -0.2362
# L Mid posterior insula                    -0.0288 0.0361    0.4280 -0.1171
# L PAG                                      0.0193 0.0628    0.7591 -0.1342
# L Thalamus (emoproxI shock intersection)  -0.0023 0.0463    0.9606 -0.1156
# PCC (1)                                    0.1412 0.0849    0.1020 -0.0666
# PCC (2)                                    0.0570 0.1007    0.5740 -0.1895
# R  BST                                     0.1376 0.0765    0.0777 -0.0497
# R aMCC                                    -0.0977 0.0726    0.1842 -0.2753
# R Amygdala (BLBM)                          0.0304 0.0780    0.6981 -0.1605
# R Amygdala (CeME)                          0.0231 0.1043    0.8256 -0.2322
# R Anterior dorsal insula                  -0.0332 0.0388    0.3963 -0.1282
# R Anterior hippocampus                    -0.0259 0.0585    0.6594 -0.1691
# R Anterior ventral insula (anterior pole)  0.0255 0.0478    0.5950 -0.0913
# R Mid posterior insula                    -0.0397 0.0446    0.3779 -0.1489
# R PAG                                     -0.0197 0.0741    0.7915 -0.2011
# R Thalamus (emoproxI shock intersection)  -0.0581 0.0485    0.2355 -0.1767
# vmPFC (from out lab)                       0.0710 0.0670    0.2942 -0.0930
# vmPFC (new 5mm sphere from Hartley paper)  0.0286 0.0389    0.4653 -0.0666
#                                                5%     50%    95%  97.5%
# L aMCC                                    -0.1901 -0.0752 0.0582 0.0624
# L Amygdala (BLBM)                         -0.1428  0.0128 0.1936 0.1992
# L Amygdala (CeME)                         -0.0848  0.0850 0.2821 0.2883
# L Anterior dorsal insula                  -0.0977 -0.0343 0.0394 0.0417
# L Anterior hippocampus                    -0.0769  0.0081 0.1068 0.1099
# L Anterior ventral insula (anterior pole) -0.0319  0.0215 0.0835 0.0854
# L BST                                     -0.1685 -0.0223 0.1475 0.1529
# L Mid posterior insula                    -0.0892 -0.0288 0.0413 0.0435
# L PAG                                     -0.0857  0.0193 0.1413 0.1451
# L Thalamus (emoproxI shock intersection)  -0.0798 -0.0023 0.0877 0.0905
# PCC (1)                                   -0.0009  0.1412 0.3062 0.3113
# PCC (2)                                   -0.1115  0.0570 0.2527 0.2588
# R  BST                                     0.0095  0.1376 0.2863 0.2910
# R aMCC                                    -0.2191 -0.0977 0.0434 0.0479
# R Amygdala (BLBM)                         -0.1001  0.0304 0.1821 0.1868
# R Amygdala (CeME)                         -0.1514  0.0231 0.2258 0.2322
# R Anterior dorsal insula                  -0.0981 -0.0332 0.0423 0.0446
# R Anterior hippocampus                    -0.1238 -0.0259 0.0878 0.0914
# R Anterior ventral insula (anterior pole) -0.0544  0.0255 0.1183 0.1212
# R Mid posterior insula                    -0.1144 -0.0397 0.0471 0.0498
# R PAG                                     -0.1437 -0.0197 0.1244 0.1289
# R Thalamus (emoproxI shock intersection)  -0.1392 -0.0581 0.0361 0.0390
# vmPFC (from out lab)                      -0.0412  0.0710 0.2013 0.2054
# vmPFC (new 5mm sphere from Hartley paper) -0.0365  0.0286 0.1042 0.1065
# ======================================== Posteriors for STATEmean ====================================================
# Warning message in melt(data_trans, id = c("ROI", "X")):
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(data_trans). In the next version, this warning will become an error.”
# Picking joint bandwidth of 0.00401
# plot without title

# %%
ii = 3
cat(sprintf('===== Summary of region effects for %s (RBA results) =====', EOIq[ii]), sep = '\n', append=TRUE)
ps0 <- psROI(aa, bb, EOIq[ii])
gg_brm <- sumROI(ps0, ns, nfigs)
#gg_brm$ROI <- factor(rownames(gg_brm))
cat(capture.output(gg_brm), sep = '\n', append=TRUE)

cat(sprintf('=================================================================================================================='),sep='\n')
cat(sprintf('===== Summary of region effects under GLM for %s (for reference only): no adjustment for multiplicity =====', EOIq[ii]),sep = '\n', append=TRUE)
mm <- list()
GLM <- as.formula(paste('Y ~ ',mod))
if(SCALE!=1) dataTable$Y <- (dataTable$Y)/SCALE  # scale back for GLM
for(kk in levels(dataTable$ROI)) mm[[kk]] = lm(GLM, data=dataTable[dataTable$ROI==kk,])
nn <- lapply(mm, summary)
ll <- lapply(nn, `[`, 'coefficients')
gg_glm <- sumGLM(ll, EOIq[ii], nR, nn[[ii]]$df, nfigs)
gg_glm = as.data.frame(gg_glm)
cat(capture.output(gg_glm),sep = '\n', append=TRUE)

cat(sprintf('======================================== Posteriors for %s ====================================================',EOIq[ii],sep='\n'))
plotPDP(ps0,gg_brm,gg_glm)
# Out:
# ===== Summary of region effects for TRAITmean (RBA results) =====
#                                              mean     SD     P+    2.5%      5%
# L aMCC                                    -0.0073 0.0297 0.4007 -0.0649 -0.0555
# L Amygdala (BLBM)                         -0.0096 0.0299 0.3716 -0.0678 -0.0585
# L Amygdala (CeME)                         -0.0100 0.0302 0.3695 -0.0696 -0.0598
# L Anterior dorsal insula                  -0.0105 0.0299 0.3608 -0.0687 -0.0597
# L Anterior hippocampus                    -0.0071 0.0298 0.3999 -0.0651 -0.0554
# L Anterior ventral insula (anterior pole) -0.0069 0.0300 0.4062 -0.0651 -0.0556
# L BST                                     -0.0066 0.0318 0.4148 -0.0686 -0.0586
# L Mid posterior insula                    -0.0068 0.0298 0.4070 -0.0649 -0.0552
# L PAG                                     -0.0091 0.0297 0.3770 -0.0671 -0.0577
# L Thalamus (emoproxI shock intersection)  -0.0111 0.0301 0.3550 -0.0705 -0.0607
# PCC (1)                                   -0.0137 0.0317 0.3354 -0.0784 -0.0661
# PCC (2)                                   -0.0092 0.0314 0.3850 -0.0711 -0.0607
# R  BST                                    -0.0097 0.0325 0.3788 -0.0739 -0.0634
# R aMCC                                    -0.0078 0.0306 0.3942 -0.0677 -0.0579
# R Amygdala (BLBM)                         -0.0054 0.0305 0.4226 -0.0643 -0.0544
# R Amygdala (CeME)                         -0.0056 0.0302 0.4201 -0.0637 -0.0543
# R Anterior dorsal insula                  -0.0095 0.0296 0.3735 -0.0674 -0.0582
# R Anterior hippocampus                    -0.0048 0.0299 0.4334 -0.0625 -0.0535
# R Anterior ventral insula (anterior pole) -0.0075 0.0301 0.4024 -0.0657 -0.0566
# R Mid posterior insula                    -0.0068 0.0299 0.4066 -0.0644 -0.0551
# R PAG                                     -0.0093 0.0299 0.3750 -0.0676 -0.0586
# R Thalamus (emoproxI shock intersection)  -0.0093 0.0297 0.3760 -0.0679 -0.0582
# vmPFC (from out lab)                      -0.0061 0.0302 0.4178 -0.0649 -0.0548
# vmPFC (new 5mm sphere from Hartley paper) -0.0106 0.0300 0.3613 -0.0699 -0.0599
#                                               50%    95%  97.5%
# L aMCC                                    -0.0075 0.0417 0.0513
# L Amygdala (BLBM)                         -0.0096 0.0393 0.0493
# L Amygdala (CeME)                         -0.0099 0.0392 0.0488
# L Anterior dorsal insula                  -0.0106 0.0382 0.0489
# L Anterior hippocampus                    -0.0074 0.0423 0.0519
# L Anterior ventral insula (anterior pole) -0.0070 0.0422 0.0525
# L BST                                     -0.0069 0.0462 0.0571
# L Mid posterior insula                    -0.0067 0.0424 0.0525
# L PAG                                     -0.0089 0.0394 0.0492
# L Thalamus (emoproxI shock intersection)  -0.0109 0.0381 0.0481
# PCC (1)                                   -0.0132 0.0369 0.0470
# PCC (2)                                   -0.0091 0.0417 0.0520
# R  BST                                    -0.0098 0.0435 0.0544
# R aMCC                                    -0.0080 0.0431 0.0527
# R Amygdala (BLBM)                         -0.0058 0.0454 0.0561
# R Amygdala (CeME)                         -0.0061 0.0449 0.0546
# R Anterior dorsal insula                  -0.0096 0.0387 0.0483
# R Anterior hippocampus                    -0.0052 0.0449 0.0549
# R Anterior ventral insula (anterior pole) -0.0075 0.0423 0.0522
# R Mid posterior insula                    -0.0069 0.0423 0.0528
# R PAG                                     -0.0093 0.0398 0.0502
# R Thalamus (emoproxI shock intersection)  -0.0093 0.0396 0.0493
# vmPFC (from out lab)                      -0.0062 0.0433 0.0540
# vmPFC (new 5mm sphere from Hartley paper) -0.0105 0.0385 0.0482
# ==================================================================================================================
# ===== Summary of region effects under GLM for TRAITmean (for reference only): no adjustment for multiplicity =====
#                                              mean     SD 2-sided-p    2.5%
# L aMCC                                     0.0422 0.0665    0.5279 -0.1204
# L Amygdala (BLBM)                         -0.0365 0.0901    0.6869 -0.2569
# L Amygdala (CeME)                         -0.0602 0.0982    0.5427 -0.3005
# L Anterior dorsal insula                  -0.0155 0.0367    0.6750 -0.1053
# L Anterior hippocampus                     0.0076 0.0492    0.8775 -0.1127
# L Anterior ventral insula (anterior pole)  0.0069 0.0309    0.8244 -0.0687
# L BST                                      0.0639 0.0846    0.4532 -0.1431
# L Mid posterior insula                     0.0195 0.0349    0.5793 -0.0660
# L PAG                                     -0.0214 0.0608    0.7254 -0.1701
# L Thalamus (emoproxI shock intersection)  -0.0393 0.0448    0.3846 -0.1490
# PCC (1)                                   -0.1492 0.0822    0.0750 -0.3503
# PCC (2)                                   -0.0818 0.0975    0.4053 -0.3204
# R  BST                                    -0.0030 0.0741    0.9683 -0.1843
# R aMCC                                     0.0545 0.0703    0.4414 -0.1175
# R Amygdala (BLBM)                         -0.0245 0.0756    0.7468 -0.2094
# R Amygdala (CeME)                          0.0229 0.1010    0.8213 -0.2242
# R Anterior dorsal insula                  -0.0019 0.0376    0.9592 -0.0939
# R Anterior hippocampus                     0.0489 0.0567    0.3917 -0.0897
# R Anterior ventral insula (anterior pole)  0.0267 0.0462    0.5658 -0.0864
# R Mid posterior insula                     0.0500 0.0432    0.2524 -0.0558
# R PAG                                     -0.0088 0.0718    0.9026 -0.1845
# R Thalamus (emoproxI shock intersection)   0.0114 0.0469    0.8083 -0.1034
# vmPFC (from out lab)                      -0.0616 0.0649    0.3465 -0.2205
# vmPFC (new 5mm sphere from Hartley paper) -0.0423 0.0377    0.2656 -0.1345
#                                                5%     50%    95%  97.5%
# L aMCC                                    -0.0690  0.0422 0.1714 0.1754
# L Amygdala (BLBM)                         -0.1872 -0.0365 0.1385 0.1440
# L Amygdala (CeME)                         -0.2245 -0.0602 0.1307 0.1367
# L Anterior dorsal insula                  -0.0769 -0.0155 0.0558 0.0581
# L Anterior hippocampus                    -0.0746  0.0076 0.1032 0.1061
# L Anterior ventral insula (anterior pole) -0.0448  0.0069 0.0669 0.0688
# L BST                                     -0.0776  0.0639 0.2283 0.2335
# L Mid posterior insula                    -0.0390  0.0195 0.0874 0.0895
# L PAG                                     -0.1231 -0.0214 0.0966 0.1003
# L Thalamus (emoproxI shock intersection)  -0.1143 -0.0393 0.0478 0.0505
# PCC (1)                                   -0.2867 -0.1492 0.0106 0.0156
# PCC (2)                                   -0.2449 -0.0818 0.1077 0.1136
# R  BST                                    -0.1269 -0.0030 0.1410 0.1455
# R aMCC                                    -0.0631  0.0545 0.1911 0.1954
# R Amygdala (BLBM)                         -0.1509 -0.0245 0.1223 0.1269
# R Amygdala (CeME)                         -0.1461  0.0229 0.2192 0.2253
# R Anterior dorsal insula                  -0.0648 -0.0019 0.0711 0.0734
# R Anterior hippocampus                    -0.0459  0.0489 0.1590 0.1625
# R Anterior ventral insula (anterior pole) -0.0506  0.0267 0.1166 0.1194
# R Mid posterior insula                    -0.0223  0.0500 0.1340 0.1366
# R PAG                                     -0.1289 -0.0088 0.1307 0.1350
# R Thalamus (emoproxI shock intersection)  -0.0671  0.0114 0.1026 0.1055
# vmPFC (from out lab)                      -0.1702 -0.0616 0.0645 0.0685
# vmPFC (new 5mm sphere from Hartley paper) -0.1053 -0.0423 0.0308 0.0331
# ======================================== Posteriors for TRAITmean ====================================================
# Warning message in melt(data_trans, id = c("ROI", "X")):
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(data_trans). In the next version, this warning will become an error.”
# Picking joint bandwidth of 0.00373
# plot without title

# %%
ii = 4
cat(sprintf('===== Summary of region effects for %s (RBA results) =====', EOIq[ii]), sep = '\n', append=TRUE)
ps0 <- psROI(aa, bb, EOIq[ii])
gg_brm <- sumROI(ps0, ns, nfigs)
#gg_brm$ROI <- factor(rownames(gg_brm))
cat(capture.output(gg_brm), sep = '\n', append=TRUE)

cat(sprintf('=================================================================================================================='),sep='\n')
cat(sprintf('===== Summary of region effects under GLM for %s (for reference only): no adjustment for multiplicity =====', EOIq[ii]),sep = '\n', append=TRUE)
mm <- list()
GLM <- as.formula(paste('Y ~ ',mod))
if(SCALE!=1) dataTable$Y <- (dataTable$Y)/SCALE  # scale back for GLM
for(kk in levels(dataTable$ROI)) mm[[kk]] = lm(GLM, data=dataTable[dataTable$ROI==kk,])
nn <- lapply(mm, summary)
ll <- lapply(nn, `[`, 'coefficients')
gg_glm <- sumGLM(ll, EOIq[ii], nR, nn[[ii]]$df, nfigs)
gg_glm = as.data.frame(gg_glm)
cat(capture.output(gg_glm),sep = '\n', append=TRUE)

cat(sprintf('======================================== Posteriors for %s ====================================================',EOIq[ii],sep='\n'))
plotPDP(ps0,gg_brm,gg_glm)
# Out:
# ===== Summary of region effects for STATEdiff (RBA results) =====
#                                              mean     SD     P+    2.5%      5%
# L aMCC                                     0.0093 0.0316 0.6136 -0.0516 -0.0418
# L Amygdala (BLBM)                          0.0013 0.0322 0.5149 -0.0618 -0.0517
# L Amygdala (CeME)                          0.0062 0.0348 0.5669 -0.0618 -0.0503
# L Anterior dorsal insula                   0.0263 0.0316 0.7968 -0.0344 -0.0245
# L Anterior hippocampus                    -0.0009 0.0305 0.4884 -0.0609 -0.0508
# L Anterior ventral insula (anterior pole) -0.0297 0.0320 0.1750 -0.0944 -0.0839
# L BST                                      0.0494 0.0402 0.8908 -0.0258 -0.0147
# L Mid posterior insula                     0.0035 0.0300 0.5486 -0.0557 -0.0460
# L PAG                                      0.0038 0.0308 0.5472 -0.0565 -0.0466
# L Thalamus (emoproxI shock intersection)   0.0027 0.0301 0.5376 -0.0572 -0.0470
# PCC (1)                                   -0.0512 0.0387 0.0858 -0.1316 -0.1176
# PCC (2)                                   -0.0544 0.0413 0.0870 -0.1396 -0.1259
# R  BST                                     0.0255 0.0430 0.7206 -0.0535 -0.0418
# R aMCC                                    -0.0084 0.0336 0.4064 -0.0761 -0.0648
# R Amygdala (BLBM)                          0.0353 0.0366 0.8372 -0.0330 -0.0219
# R Amygdala (CeME)                          0.0217 0.0328 0.7448 -0.0408 -0.0310
# R Anterior dorsal insula                  -0.0042 0.0297 0.4444 -0.0626 -0.0531
# R Anterior hippocampus                     0.0049 0.0314 0.5583 -0.0560 -0.0463
# R Anterior ventral insula (anterior pole) -0.0282 0.0324 0.1939 -0.0945 -0.0826
# R Mid posterior insula                    -0.0147 0.0303 0.3130 -0.0751 -0.0648
# R PAG                                     -0.0126 0.0310 0.3468 -0.0753 -0.0642
# R Thalamus (emoproxI shock intersection)   0.0057 0.0306 0.5714 -0.0538 -0.0448
# vmPFC (from out lab)                      -0.0158 0.0323 0.3114 -0.0802 -0.0696
# vmPFC (new 5mm sphere from Hartley paper) -0.0272 0.0314 0.1948 -0.0903 -0.0794
#                                               50%    95%  97.5%
# L aMCC                                     0.0085 0.0620 0.0737
# L Amygdala (BLBM)                          0.0012 0.0545 0.0663
# L Amygdala (CeME)                          0.0056 0.0637 0.0767
# L Anterior dorsal insula                   0.0256 0.0791 0.0893
# L Anterior hippocampus                    -0.0009 0.0496 0.0596
# L Anterior ventral insula (anterior pole) -0.0288 0.0215 0.0309
# L BST                                      0.0484 0.1166 0.1301
# L Mid posterior insula                     0.0036 0.0529 0.0633
# L PAG                                      0.0036 0.0549 0.0650
# L Thalamus (emoproxI shock intersection)   0.0028 0.0519 0.0617
# PCC (1)                                   -0.0492 0.0091 0.0194
# PCC (2)                                   -0.0525 0.0097 0.0204
# R  BST                                     0.0234 0.0996 0.1169
# R aMCC                                    -0.0077 0.0459 0.0563
# R Amygdala (BLBM)                          0.0335 0.0981 0.1115
# R Amygdala (CeME)                          0.0211 0.0768 0.0877
# R Anterior dorsal insula                  -0.0043 0.0442 0.0536
# R Anterior hippocampus                     0.0044 0.0577 0.0677
# R Anterior ventral insula (anterior pole) -0.0274 0.0234 0.0328
# R Mid posterior insula                    -0.0142 0.0341 0.0446
# R PAG                                     -0.0119 0.0365 0.0468
# R Thalamus (emoproxI shock intersection)   0.0055 0.0563 0.0668
# vmPFC (from out lab)                      -0.0155 0.0369 0.0475
# vmPFC (new 5mm sphere from Hartley paper) -0.0265 0.0231 0.0333
# ==================================================================================================================
# ===== Summary of region effects under GLM for STATEdiff (for reference only): no adjustment for multiplicity =====
#                                              mean     SD 2-sided-p    2.5%
# L aMCC                                     0.0561 0.0521    0.2864 -0.0714
# L Amygdala (BLBM)                          0.0712 0.0706    0.3172 -0.1014
# L Amygdala (CeME)                          0.0302 0.0769    0.6962 -0.1581
# L Anterior dorsal insula                   0.0434 0.0288    0.1367 -0.0269
# L Anterior hippocampus                    -0.0004 0.0385    0.9927 -0.0946
# L Anterior ventral insula (anterior pole) -0.0524 0.0242    0.0348 -0.1116
# L BST                                      0.1250 0.0663    0.0646 -0.0372
# L Mid posterior insula                     0.0132 0.0274    0.6304 -0.0537
# L PAG                                      0.0164 0.0476    0.7321 -0.1001
# L Thalamus (emoproxI shock intersection)   0.0090 0.0351    0.7995 -0.0770
# PCC (1)                                   -0.0914 0.0644    0.1614 -0.2490
# PCC (2)                                   -0.0584 0.0764    0.4475 -0.2454
# R  BST                                     0.0818 0.0581    0.1645 -0.0603
# R aMCC                                    -0.0274 0.0551    0.6203 -0.1622
# R Amygdala (BLBM)                          0.1059 0.0592    0.0792 -0.0390
# R Amygdala (CeME)                          0.0407 0.0791    0.6091 -0.1529
# R Anterior dorsal insula                  -0.0129 0.0294    0.6627 -0.0850
# R Anterior hippocampus                     0.0017 0.0444    0.9701 -0.1069
# R Anterior ventral insula (anterior pole) -0.0850 0.0362    0.0226 -0.1736
# R Mid posterior insula                    -0.0420 0.0339    0.2198 -0.1249
# R PAG                                      0.0065 0.0562    0.9089 -0.1311
# R Thalamus (emoproxI shock intersection)   0.0190 0.0368    0.6076 -0.0710
# vmPFC (from out lab)                      -0.0330 0.0509    0.5186 -0.1575
# vmPFC (new 5mm sphere from Hartley paper) -0.0303 0.0295    0.3085 -0.1025
#                                                5%     50%     95%   97.5%
# L aMCC                                    -0.0311  0.0561  0.1573  0.1604
# L Amygdala (BLBM)                         -0.0468  0.0712  0.2083  0.2126
# L Amygdala (CeME)                         -0.0985  0.0302  0.1797  0.1844
# L Anterior dorsal insula                  -0.0047  0.0434  0.0993  0.1010
# L Anterior hippocampus                    -0.0648 -0.0004  0.0745  0.0768
# L Anterior ventral insula (anterior pole) -0.0929 -0.0524 -0.0054 -0.0039
# L BST                                      0.0141  0.1250  0.2538  0.2579
# L Mid posterior insula                    -0.0325  0.0132  0.0664  0.0681
# L PAG                                     -0.0633  0.0164  0.1089  0.1118
# L Thalamus (emoproxI shock intersection)  -0.0498  0.0090  0.0772  0.0793
# PCC (1)                                   -0.1991 -0.0914  0.0337  0.0377
# PCC (2)                                   -0.1863 -0.0584  0.0900  0.0947
# R  BST                                    -0.0153  0.0818  0.1946  0.1981
# R aMCC                                    -0.1196 -0.0274  0.0796  0.0829
# R Amygdala (BLBM)                          0.0068  0.1059  0.2209  0.2245
# R Amygdala (CeME)                         -0.0917  0.0407  0.1945  0.1993
# R Anterior dorsal insula                  -0.0622 -0.0129  0.0443  0.0461
# R Anterior hippocampus                    -0.0726  0.0017  0.0879  0.0906
# R Anterior ventral insula (anterior pole) -0.1456 -0.0850 -0.0146 -0.0124
# R Mid posterior insula                    -0.0987 -0.0420  0.0238  0.0258
# R PAG                                     -0.0876  0.0065  0.1157  0.1192
# R Thalamus (emoproxI shock intersection)  -0.0425  0.0190  0.0904  0.0927
# vmPFC (from out lab)                      -0.1181 -0.0330  0.0658  0.0689
# vmPFC (new 5mm sphere from Hartley paper) -0.0797 -0.0303  0.0270  0.0288
# ======================================== Posteriors for STATEdiff ====================================================
# Warning message in melt(data_trans, id = c("ROI", "X")):
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(data_trans). In the next version, this warning will become an error.”
# Picking joint bandwidth of 0.00409
# plot without title

# %%
ii = 5
cat(sprintf('===== Summary of region effects for %s (RBA results) =====', EOIq[ii]), sep = '\n', append=TRUE)
ps0 <- psROI(aa, bb, EOIq[ii])
gg_brm <- sumROI(ps0, ns, nfigs)
#gg_brm$ROI <- factor(rownames(gg_brm))
cat(capture.output(gg_brm), sep = '\n', append=TRUE)

cat(sprintf('=================================================================================================================='),sep='\n')
cat(sprintf('===== Summary of region effects under GLM for %s (for reference only): no adjustment for multiplicity =====', EOIq[ii]),sep = '\n', append=TRUE)
mm <- list()
GLM <- as.formula(paste('Y ~ ',mod))
if(SCALE!=1) dataTable$Y <- (dataTable$Y)/SCALE  # scale back for GLM
for(kk in levels(dataTable$ROI)) mm[[kk]] = lm(GLM, data=dataTable[dataTable$ROI==kk,])
nn <- lapply(mm, summary)
ll <- lapply(nn, `[`, 'coefficients')
gg_glm <- sumGLM(ll, EOIq[ii], nR, nn[[ii]]$df, nfigs)
gg_glm = as.data.frame(gg_glm)
cat(capture.output(gg_glm),sep = '\n', append=TRUE)

cat(sprintf('======================================== Posteriors for %s ====================================================',EOIq[ii],sep='\n'))
plotPDP(ps0,gg_brm,gg_glm)
# Out:
# ===== Summary of region effects for TRAITdiff (RBA results) =====
#                                              mean     SD     P+    2.5%      5%
# L aMCC                                    -0.0049 0.0245 0.4220 -0.0541 -0.0455
# L Amygdala (BLBM)                          0.0022 0.0253 0.5265 -0.0461 -0.0385
# L Amygdala (CeME)                         -0.0024 0.0252 0.4620 -0.0523 -0.0431
# L Anterior dorsal insula                  -0.0009 0.0251 0.4878 -0.0501 -0.0417
# L Anterior hippocampus                    -0.0023 0.0246 0.4616 -0.0513 -0.0429
# L Anterior ventral insula (anterior pole) -0.0074 0.0252 0.3880 -0.0590 -0.0498
# L BST                                      0.0035 0.0284 0.5382 -0.0502 -0.0412
# L Mid posterior insula                     0.0011 0.0249 0.5141 -0.0474 -0.0391
# L PAG                                     -0.0007 0.0248 0.4894 -0.0496 -0.0408
# L Thalamus (emoproxI shock intersection)  -0.0013 0.0247 0.4778 -0.0500 -0.0417
# PCC (1)                                   -0.0125 0.0274 0.3282 -0.0703 -0.0597
# PCC (2)                                   -0.0125 0.0284 0.3368 -0.0726 -0.0614
# R  BST                                     0.0033 0.0288 0.5344 -0.0508 -0.0416
# R aMCC                                     0.0001 0.0256 0.4999 -0.0505 -0.0421
# R Amygdala (BLBM)                          0.0010 0.0255 0.5134 -0.0488 -0.0405
# R Amygdala (CeME)                          0.0001 0.0250 0.4978 -0.0489 -0.0401
# R Anterior dorsal insula                  -0.0028 0.0245 0.4558 -0.0515 -0.0427
# R Anterior hippocampus                     0.0009 0.0249 0.5099 -0.0471 -0.0390
# R Anterior ventral insula (anterior pole) -0.0050 0.0249 0.4212 -0.0547 -0.0464
# R Mid posterior insula                     0.0022 0.0253 0.5264 -0.0460 -0.0382
# R PAG                                     -0.0057 0.0250 0.4119 -0.0562 -0.0473
# R Thalamus (emoproxI shock intersection)  -0.0023 0.0245 0.4636 -0.0515 -0.0426
# vmPFC (from out lab)                      -0.0060 0.0252 0.4076 -0.0573 -0.0479
# vmPFC (new 5mm sphere from Hartley paper) -0.0087 0.0256 0.3730 -0.0617 -0.0522
#                                               50%    95%  97.5%
# L aMCC                                    -0.0047 0.0352 0.0427
# L Amygdala (BLBM)                          0.0016 0.0444 0.0530
# L Amygdala (CeME)                         -0.0023 0.0389 0.0471
# L Anterior dorsal insula                  -0.0008 0.0405 0.0483
# L Anterior hippocampus                    -0.0022 0.0382 0.0455
# L Anterior ventral insula (anterior pole) -0.0068 0.0327 0.0412
# L BST                                      0.0026 0.0510 0.0614
# L Mid posterior insula                     0.0008 0.0426 0.0506
# L PAG                                     -0.0006 0.0399 0.0480
# L Thalamus (emoproxI shock intersection)  -0.0013 0.0392 0.0471
# PCC (1)                                   -0.0114 0.0302 0.0386
# PCC (2)                                   -0.0111 0.0315 0.0402
# R  BST                                     0.0023 0.0517 0.0643
# R aMCC                                     0.0000 0.0422 0.0507
# R Amygdala (BLBM)                          0.0007 0.0432 0.0521
# R Amygdala (CeME)                         -0.0001 0.0416 0.0502
# R Anterior dorsal insula                  -0.0027 0.0373 0.0455
# R Anterior hippocampus                     0.0006 0.0421 0.0505
# R Anterior ventral insula (anterior pole) -0.0048 0.0352 0.0432
# R Mid posterior insula                     0.0016 0.0448 0.0539
# R PAG                                     -0.0053 0.0348 0.0424
# R Thalamus (emoproxI shock intersection)  -0.0022 0.0380 0.0461
# vmPFC (from out lab)                      -0.0059 0.0348 0.0429
# vmPFC (new 5mm sphere from Hartley paper) -0.0081 0.0320 0.0398
# ==================================================================================================================
# ===== Summary of region effects under GLM for TRAITdiff (for reference only): no adjustment for multiplicity =====
#                                              mean     SD 2-sided-p    2.5%
# L aMCC                                    -0.0491 0.0532    0.3604 -0.1792
# L Amygdala (BLBM)                         -0.0091 0.0721    0.9001 -0.1854
# L Amygdala (CeME)                         -0.0904 0.0786    0.2548 -0.2827
# L Anterior dorsal insula                  -0.0170 0.0294    0.5643 -0.0889
# L Anterior hippocampus                     0.0055 0.0393    0.8886 -0.0907
# L Anterior ventral insula (anterior pole) -0.0241 0.0247    0.3332 -0.0846
# L BST                                      0.0110 0.0677    0.8713 -0.1546
# L Mid posterior insula                     0.0356 0.0279    0.2078 -0.0328
# L PAG                                      0.0184 0.0486    0.7072 -0.1006
# L Thalamus (emoproxI shock intersection)  -0.0013 0.0359    0.9705 -0.0891
# PCC (1)                                   -0.0540 0.0658    0.4150 -0.2149
# PCC (2)                                   -0.0292 0.0780    0.7098 -0.2201
# R  BST                                     0.0526 0.0593    0.3785 -0.0924
# R aMCC                                    -0.0191 0.0562    0.7353 -0.1567
# R Amygdala (BLBM)                         -0.0350 0.0604    0.5650 -0.1829
# R Amygdala (CeME)                         -0.0154 0.0808    0.8491 -0.2132
# R Anterior dorsal insula                  -0.0102 0.0301    0.7370 -0.0837
# R Anterior hippocampus                     0.0195 0.0453    0.6695 -0.0915
# R Anterior ventral insula (anterior pole)  0.0161 0.0370    0.6646 -0.0744
# R Mid posterior insula                     0.0612 0.0346    0.0821 -0.0234
# R PAG                                     -0.0648 0.0574    0.2643 -0.2053
# R Thalamus (emoproxI shock intersection)  -0.0156 0.0375    0.6802 -0.1074
# vmPFC (from out lab)                      -0.0472 0.0519    0.3670 -0.1743
# vmPFC (new 5mm sphere from Hartley paper) -0.0452 0.0301    0.1391 -0.1189
#                                                5%     50%    95%  97.5%
# L aMCC                                    -0.1380 -0.0491 0.0543 0.0575
# L Amygdala (BLBM)                         -0.1296 -0.0091 0.1309 0.1353
# L Amygdala (CeME)                         -0.2219 -0.0904 0.0623 0.0671
# L Anterior dorsal insula                  -0.0662 -0.0170 0.0400 0.0418
# L Anterior hippocampus                    -0.0603  0.0055 0.0820 0.0844
# L Anterior ventral insula (anterior pole) -0.0655 -0.0241 0.0239 0.0254
# L BST                                     -0.1022  0.0110 0.1426 0.1467
# L Mid posterior insula                    -0.0111  0.0356 0.0899 0.0916
# L PAG                                     -0.0630  0.0184 0.1128 0.1158
# L Thalamus (emoproxI shock intersection)  -0.0613 -0.0013 0.0684 0.0705
# PCC (1)                                   -0.1640 -0.0540 0.0738 0.0778
# PCC (2)                                   -0.1597 -0.0292 0.1224 0.1272
# R  BST                                    -0.0465  0.0526 0.1678 0.1714
# R aMCC                                    -0.1132 -0.0191 0.0902 0.0936
# R Amygdala (BLBM)                         -0.1361 -0.0350 0.0825 0.0861
# R Amygdala (CeME)                         -0.1506 -0.0154 0.1416 0.1465
# R Anterior dorsal insula                  -0.0605 -0.0102 0.0483 0.0501
# R Anterior hippocampus                    -0.0564  0.0195 0.1075 0.1103
# R Anterior ventral insula (anterior pole) -0.0458  0.0161 0.0880 0.0903
# R Mid posterior insula                     0.0034  0.0612 0.1284 0.1305
# R PAG                                     -0.1609 -0.0648 0.0468 0.0503
# R Thalamus (emoproxI shock intersection)  -0.0784 -0.0156 0.0574 0.0597
# vmPFC (from out lab)                      -0.1341 -0.0472 0.0537 0.0568
# vmPFC (new 5mm sphere from Hartley paper) -0.0956 -0.0452 0.0133 0.0152
# ======================================== Posteriors for TRAITdiff ====================================================
# Warning message in melt(data_trans, id = c("ROI", "X")):
# “The melt generic in data.table has been passed a data.frame and will attempt to redirect to the relevant reshape2 method; please note that reshape2 is deprecated, and this redirection is now deprecated as well. To continue using melt methods from reshape2 while both libraries are attached, e.g. melt.list, you can prepend the namespace like reshape2::melt(data_trans). In the next version, this warning will become an error.”

# %% [markdown]
# # **3. Posterior Predictive Check**

# %%
pp_plot = pp_check(fm,nsamples = 100)

# %%
pp_plot + xlim(-1.5,1.5) + theme(text = element_text(size=25),legend.text=element_text(size=25)) + ggtitle("Model 1: Varying Intercepts and Slopes",)
